# %% [markdown]
# ![image.png](attachment:11b42fe8-5b85-4293-b08a-c686220b29d4.png)![image.png](attachment:49c22934-d9db-4487-98ac-153675a02745.png)

# %% [markdown]
# $$
# Y = \beta_0 + \beta_1 X
# $$

# %% [markdown]
# ![image.png](attachment:e79e108d-7f66-41e5-bbe6-4c8048bec100.png)
#
# configuración base
